# %% [markdown]
# # Importing the data

# %%
# %matplotlib inline
import math
import numpy as np
import pandas as pd
from pandas.plotting import scatter_matrix
from sklearn import metrics
from sklearn.metrics import accuracy_score as acs
from sklearn.metrics import precision_score as pcs
from sklearn.linear_model import RidgeClassifier
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("heart_statlog_cleveland_hungary_final.csv")
df.head()
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
df.describe()
# Out:
#                age          sex  chest pain type  resting bp s  cholesterol  \
# count  1190.000000  1190.000000      1190.000000   1190.000000  1190.000000
# mean     53.720168     0.763866         3.232773    132.153782   210.363866
# std       9.358203     0.424884         0.935480     18.368823   101.420489
# min      28.000000     0.000000         1.000000      0.000000     0.000000
# 25%      47.000000     1.000000         3.000000    120.000000   188.000000
# 50%      54.000000     1.000000         4.000000    130.000000   229.000000
# 75%      60.000000     1.000000         4.000000    140.000000   269.750000
# max      77.000000     1.000000         4.000000    200.000000   603.000000
#
#        fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# count          1190.000000  1190.000000     1190.000000      1190.000000
# mean              0.213445     0.698319      139.732773         0.387395
# std               0.409912     0.870359       25.517636         0.487360
# min               0.000000     0.000000       60.000000         0.000000
# 25%               0.000000     0.000000      121.000000         0.000000
# 50%               0.000000     0.000000      140.500000         0.000000
# 75%               0.000000     2.000000      160.000000         1.000000
# max               1.000000     2.000000      202.000000         1.000000
#
#            oldpeak     ST slope       target
# count  1190.000000  1190.000000  1190.000000
# mean      0.922773     1.624370     0.528571
# std       1.086337     0.610459     0.499393
# min      -2.600000     0.000000     0.000000
# 25%       0.000000     1.000000     0.000000
# 50%       0.600000     2.000000     1.000000
# 75%       1.600000     2.000000     1.000000
# max       6.200000     3.000000     1.000000

# %%
print(df.dtypes)
# Out:
# age                      int64
# sex                      int64
# chest pain type          int64
# resting bp s             int64
# cholesterol              int64
# fasting blood sugar      int64
# resting ecg              int64
# max heart rate           int64
# exercise angina          int64
# oldpeak                float64
# ST slope                 int64
# target                   int64
# dtype: object

# %% [markdown]
# # Remove Null Values

# %%
df.isnull().sum()
# Out:
# age                    0
# sex                    0
# chest pain type        0
# resting bp s           0
# cholesterol            0
# fasting blood sugar    0
# resting ecg            0
# max heart rate         0
# exercise angina        0
# oldpeak                0
# ST slope               0
# target                 0
# dtype: int64

# %%
#Null removal not required

# %% [markdown]
# # Discovery and Visualisation

# %% [markdown]
# ## Disease rates

# %%
print(df['sex'].unique())
print("______")
print(df['chest pain type'].unique())
print("______")
print(df['fasting blood sugar'].unique())
print("______")
print(df['resting ecg'].unique())
print("______")
print(df['ST slope'].unique())
print("______")
# Out:
# [1 0]
# ______
# [2 3 4 1]
# ______
# [0 1]
# ______
# [0 1 2]
# ______
# [1 2 3 0]
# ______

# %% [markdown]
# *sex* 1 - male, 0 - female <br>
# *chest pain type* 1 - typical angina, 2 - atypical angina, 3 - non-anginal pain, 4 - asymptomatic <br>
# *fasting blood* sugar 1 > 120mg/dk, 2 < 120 mg/dl <br>
# *resting ecg* results 0 - normal, 1, ST-T wave abnormality, 2 - left ventricular hypertrophy<br>
# *ST slope 1* - upsloping, 2 - flat, 3 - downsloping<br>

# %%
plt.figure(figsize = (15, 6))
plot_params1 = {'kind':'pie', 'startangle': 90, 'autopct':'%1.1f%%', 'colors':['red', 'green']}
plot_params2 = {'kind':'pie', 'startangle': 90, 'autopct':'%1.1f%%', 'colors':['green', 'red']}

# how many have disease vs how many don't
plt.subplot2grid((2,4), (0,0))
df.target.value_counts() \
.plot(title='Total disease rate', **plot_params1).axis('equal')


# disease rate wrt Sex
df_male = df.target[df['sex'] == 1].value_counts(normalize=True, sort=False)
df_female = df.target[df['sex'] == 0].value_counts(normalize=True, sort=False)

## male disease plot
plt.subplot2grid((2,4),(0,1))
df_male.plot(title='Male disease rate', **plot_params2).axis('equal')

## female survival plot
plt.subplot2grid((2,4),(0,2))
df_female.plot(title='Female disease rate', **plot_params2).axis('equal')



# Survival rate wrt chest pain type
df_tangina = df.target[df['chest pain type'] == 1].value_counts(normalize=True, sort=False)
df_atangina = df.target[df['chest pain type'] == 2].value_counts(normalize=True, sort=False)
df_nonangina = df.target[df['chest pain type'] == 3].value_counts(normalize=True, sort=False)
df_asympt = df.target[df['chest pain type'] == 4].value_counts(normalize=True, sort=False)


## typical angina
plt.subplot2grid((2,4),(1,0))
df_tangina.plot(title='typical anginal pain-disease rate', **plot_params2).axis('equal')

## typical angina
plt.subplot2grid((2,4),(1,1))
df_atangina.plot(title='atypical anginal pain-disease rate', **plot_params2).axis('equal')

## typical angina
plt.subplot2grid((2,4),(1,2))
df_nonangina.plot(title='non-anginal pain-disease rate', **plot_params2).axis('equal')

## typical angina
plt.subplot2grid((2,4),(1,3))
df_asympt.plot(title='asymptomatic pain-disease rate', **plot_params2).axis('equal')


plt.show()

# %% [markdown]
# This is just an example of what the data looks like. <br>
# The data is quite balanced, as both values of target are almsot equally present.<br>
# As you can see, males are more likely to have heart disease. Interestingly, of the patients that report no pain, 77.3% have heart disease.

# %%
plt.figure(figsize=(13,4))

# plots a bar graph of the age distribution
df.age.plot(kind='kde', alpha=0.6, title='Age distribution', xlim=(0, 100))

plt.show()

# %% [markdown]
# Most of the cases are seen in people near 60 years of age

# %%
fig = plt.figure(figsize=(8,6))
sns.heatmap(df.corr(method = 'pearson'), square= True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# *Correlation matrix*
# Here, we can see that the features that have the highest correlation to target are chest pain type, exercise angina, ST slope, and max heart rate. Basic algorithms are expected to work off of these the most to find the classification model.

# %%
corr_matrix = df.corr()
corr_matrix['target'].sort_values(ascending=False)
# Out:
# target                 1.000000
# ST slope               0.505608
# exercise angina        0.481467
# chest pain type        0.460127
# oldpeak                0.398385
# sex                    0.311267
# age                    0.262029
# fasting blood sugar    0.216695
# resting bp s           0.121415
# resting ecg            0.073059
# cholesterol           -0.198366
# max heart rate        -0.413278
# Name: target, dtype: float64

# %%
scatter_matrix(df, alpha = 0.2, figsize=(12,8), diagonal='hist')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026C92C560C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C92D66E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C92D98E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C92F61D48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C92F99E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C92FD1F48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9228ADC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C92C38B48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C92DFC4C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C92BC88C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C922AE6C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C92A48308>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026C92AC6048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C92B90148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C92A82248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C92B39388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C92B14488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C92E2F508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C92E6CE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C92EA0748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C92EDA848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C92F13988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9300BA48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93044B48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9307CC48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C930B5D88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C930EEE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93125F48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C931630C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9319C1C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C931D42C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9320D408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93246488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9327F588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C932B86C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C932F07C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026C933298C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93362988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9339BA88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C933D3B88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9340CCC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93444DC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9347CE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C934B5FC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C934F2148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9352B248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93563348>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9359D488>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026C935D54C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9360F5C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93647708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93681808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C936BA908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C936F2A08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9372AB08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93762C08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9379BD48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C937D5E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9380DF08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9384A088>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93883188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C938BB288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C938F43C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9392E088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C939654C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9399F608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C939D8748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93A10848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93A49948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93A80A08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93AB8B08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93AF3C08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93B2BD48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93B63E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93B9CF08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93BD9088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93C12188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93C4B288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93C833C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93CBC448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93CF5548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93D34E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93D66788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93DA0888>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93DD7948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93E11A88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93E4AB88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93E83C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93EBBDC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93EF4EC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93F2BF48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93F690C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93FA31C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93FDB2C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C94014408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9404C488>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026C94084588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C940BD6C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C940F67C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9412F8C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C941689C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C941A2AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C941DABC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C94213D08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9424CE08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C94283EC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C942BCFC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C942F8148>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026C94330248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9436A348>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C943A4408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C943DC508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C94416608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9444E748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C94487848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C944C0908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C944F7A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C94530B48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C94569C48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C945A2D88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026C945DBE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C94613E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9464BFC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C94688108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C946C0208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C946F9348>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C947323C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9573A4C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C95775608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C957AF708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C957E8808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9581F8C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026C958589C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C95891AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C958C8BC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C95901D08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C95939E08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C95972EC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C959B1048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C959E9148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C95A22248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C95A5B388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C95A93408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C95ACC508>]],
#       dtype=object)

# %% [markdown]
# Visualising the correlation between data

# %% [markdown]
# # Scaling and Splitting

# %%
X = df.iloc[:,:-1].values
y = df.iloc[:, -1].values

# %%
X[1]
# Out:
# array([ 49.,   0.,   3., 160., 180.,   0.,   0., 156.,   0.,   1.,   2.])

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
X[1]
# Out:
# array([-0.50460037, -1.79857595, -0.24893198,  1.51658739, -0.29951178,
#        -0.52092948, -0.80267229,  0.63775761, -0.79521891,  0.07111913,
#         0.61558278])

# %%
sss = StratifiedShuffleSplit(n_splits=2, test_size=0.3, random_state=32)
for train_index, test_index in sss.split(X,y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

# %% [markdown]
# # Classification

# %% [markdown]
# ## Ridge Classifier

# %%
rcc = RidgeClassifier(normalize = False, copy_X = True, random_state = 32)
rcc.fit(X_train, y_train)
# Out:
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                 max_iter=None, normalize=False, random_state=32, solver='auto',
#                 tol=0.001)

# %%
y_rccpred = rcc.predict(X_test)

# %%
print(metrics.classification_report(y_test, y_rccpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.83       168
#            1       0.85      0.84      0.84       189
#
#     accuracy                           0.83       357
#    macro avg       0.83      0.83      0.83       357
# weighted avg       0.83      0.83      0.83       357

# %%
sns.heatmap(metrics.confusion_matrix(y_test, y_rccpred))

# %% [markdown]
# ## Adaboost Classifier

# %%
abc = AdaBoostClassifier(n_estimators = 50, random_state = 32)
abc.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,
#                    n_estimators=50, random_state=32)

# %%
y_abcpred = abc.predict(X_test)

# %%
print(metrics.classification_report(y_test, y_abcpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.86      0.84       168
#            1       0.87      0.84      0.85       189
#
#     accuracy                           0.85       357
#    macro avg       0.85      0.85      0.85       357
# weighted avg       0.85      0.85      0.85       357

# %%
sns.heatmap(metrics.confusion_matrix(y_test, y_abcpred))

# %% [markdown]
# ## Random Forest Classifier

# %%
rfc = RandomForestClassifier(max_depth = 5, random_state = 2)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=5, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=2, verbose=0,
#                        warm_start=False)

# %%
y_rfcpred = rfc.predict(X_test)

# %%
sns.heatmap(metrics.confusion_matrix(y_test, y_rfcpred))

# %% [markdown]
# ## K Nearest Neighbours

# %%
k = int(math.sqrt(len(y_test)))

# %%
knn = KNeighborsClassifier(n_neighbors = 9, weights = 'distance')
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=9, p=2,
#                      weights='distance')

# %%
y_knnpred = knn.predict(X_test)

# %%
print(metrics.classification_report(y_test, y_knnpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.93       168
#            1       0.93      0.94      0.93       189
#
#     accuracy                           0.93       357
#    macro avg       0.93      0.93      0.93       357
# weighted avg       0.93      0.93      0.93       357

# %%
sns.heatmap(metrics.confusion_matrix(y_test, y_knnpred))

# %% [markdown]
# ## Gaussian Naive Bayes

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_gnbpred = gnb.predict(X_test)

# %%
print(metrics.classification_report(y_test, y_gnbpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84       168
#            1       0.87      0.83      0.85       189
#
#     accuracy                           0.84       357
#    macro avg       0.84      0.84      0.84       357
# weighted avg       0.84      0.84      0.84       357

# %%
sns.heatmap(metrics.confusion_matrix(y_test, y_gnbpred))

# %% [markdown]
# ## Multi Layer Perceptron neural network

# %%
mlp = MLPClassifier(solver = 'lbfgs', random_state = 10, max_iter = 100)
mlp.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=100,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=10, shuffle=True, solver='lbfgs',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)

# %%
y_mlppred = mlp.predict(X_test)

# %%
print(metrics.classification_report(y_test, y_mlppred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89       168
#            1       0.90      0.90      0.90       189
#
#     accuracy                           0.90       357
#    macro avg       0.90      0.90      0.90       357
# weighted avg       0.90      0.90      0.90       357

# %%
sns.heatmap(metrics.confusion_matrix(y_test, y_mlppred))

# %% [markdown]
# ## Support Vector Machines

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  # FSVM-CIL

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Results

# %%
results = {"classifier": ["Ridge", "Adaboost", "RandomForest", "KNN", "Gaussian Naive Bayes", "MultiLayer Perceptron", "SVM", "FSVM"],
          "accuracy" : [acs(y_test, y_rccpred), acs(y_test, y_abcpred), acs(y_test, y_rfcpred), acs(y_test, y_knnpred), acs(y_test, y_gnbpred), acs(y_test, y_mlppred), 0.88, 0.938],
          "precision" : [pcs(y_test, y_rccpred), pcs(y_test, y_abcpred), pcs(y_test, y_rfcpred), pcs(y_test, y_knnpred), pcs(y_test, y_gnbpred), pcs(y_test, y_mlppred), 0.85, 0.991]  
          }
results_df = pd.DataFrame(data = results)

# %%
yticks = [i/20 for i in range(0,21)]
plot_kwargs = {'grid': True,  'rot': 70, 'yticks': yticks, 'figsize': (10,10), 'fontsize' : 14}
ax = results_df.plot.bar(x="classifier", y="accuracy",  title="Accuracy of the Classifiers", **plot_kwargs)

# %%
results_df.plot.bar(x="classifier", y="precision", title="Precision of the Classifiers", **plot_kwargs)
